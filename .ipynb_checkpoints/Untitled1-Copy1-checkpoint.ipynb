# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import random
# Out:
# 2025-06-10 21:02:30.113977: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [raw]
# Daten laden

# %%
#verwende MNIST-Modul aus keras
mnist = tf.keras.datasets.cifar10

# lade Datensatz bestehend aus (Trainingspaare), (Testpaare)
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [raw]
# Normalisieren

# %%
# Normalisiere die Bilder auf das Intervall  [0, 1]
x_train  = x_train / 255.0
x_test = x_test / 255.0

# %%
print(str(len(x_train)))
# Out:
# 50000

# %% [markdown]
# Anzeigen eines belibigen Bildes

# %%
image_pos = random.randint(1,len(x_train))                
image = x_train[image_pos]
plt.imshow(image)
plt.show()

print("Image Lable:", str(y_train[image_pos]))
# Out:
# Image Lable: [5]

# %% [raw]
# Filtern nach Label

# %%
y_train, y_test = np.squeeze(y_train), np.squeeze(y_test)
class_car, class_plane = 1,0
train_mask = (y_train == class_car) | (y_train == class_plane)
test_mask = (y_test == class_car) | (y_test == class_plane)
y_train = y_train[train_mask]
y_test = y_test[test_mask]
x_train = x_train[train_mask]
x_test = x_test[test_mask]

# %%
total_classes = 2 
train_vec_labels = keras.utils.to_categorical(y_train, total_classes)
test_vec_labels = keras.utils.to_categorical(y_test, total_classes)

# %% [raw]
# Verschiedenste Parameter Testen

# %%
activations = ['sigmoid', 'relu', 'elu', 'tanh']
batchsize = [8,64,128]
epochs = [40]
points = [64,128]
hist_act = {}
for epoch in epochs:
    print("Epoch:" + str(epoch))
    for batch in batchsize:
        print("    Batch:", str(batch))
        for point in points:
            print("        Points:",str(point))
            for act in activations:
                m = Sequential([Flatten(input_shape=(32,32,3)), Dense(point, activation=act), Dense(2, activation='softmax')])
                m.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
                h = m.fit(x_train, train_vec_labels, validation_data=(x_test,test_vec_labels), epochs=epoch, batch_size=batch, verbose=0)
                print("Act:", act)
                eval_loss, eval_accuracy = m.evaluate(x_test, test_vec_labels)
                print("Model accuracy: %.2f" % eval_accuracy)
                hist_act[act] = h.history['val_accuracy'][-1]
                plt.plot(h.history['accuracy'],'o--')
                plt.plot(h.history['val_accuracy'],'o--')
                plt.title('model accuracy')
                plt.ylabel('accuracy')
                plt.xlabel('epoch')
                plt.legend(['train', 'test'], loc='upper left')
                plt.show()
# Out:
# Epoch:40
#     Batch: 8
#         Points: 64
# Act: sigmoid
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8886 - loss: 0.2567
# Model accuracy: 0.89
# Act: relu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9044 - loss: 0.2463
# Model accuracy: 0.90
# Act: elu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8966 - loss: 0.2631
# Model accuracy: 0.89
# Act: tanh
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8989 - loss: 0.2938
# Model accuracy: 0.89
#         Points: 128
# Act: sigmoid
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8848 - loss: 0.2746
# Model accuracy: 0.89
# Act: relu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9049 - loss: 0.2991
# Model accuracy: 0.90
# Act: elu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8959 - loss: 0.2814
# Model accuracy: 0.89
# Act: tanh
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8956 - loss: 0.2805
# Model accuracy: 0.90
#     Batch: 64
#         Points: 64
# Act: sigmoid
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8214 - loss: 0.3790
# Model accuracy: 0.81
# Act: relu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8904 - loss: 0.2589
# Model accuracy: 0.88
# Act: elu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8833 - loss: 0.2777
# Model accuracy: 0.88
# Act: tanh
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8812 - loss: 0.2722
# Model accuracy: 0.88
#         Points: 128
# Act: sigmoid
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8441 - loss: 0.3626
# Model accuracy: 0.84
# Act: relu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8230 - loss: 0.4011
# Model accuracy: 0.83
# Act: elu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8932 - loss: 0.2752
# Model accuracy: 0.88
# Act: tanh
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8745 - loss: 0.2922
# Model accuracy: 0.86
#     Batch: 128
#         Points: 64
# Act: sigmoid
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8022 - loss: 0.4159
# Model accuracy: 0.79
# Act: relu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8711 - loss: 0.3068
# Model accuracy: 0.87
# Act: elu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8204 - loss: 0.3732
# Model accuracy: 0.81
# Act: tanh
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8231 - loss: 0.3660
# Model accuracy: 0.81
#         Points: 128
# Act: sigmoid
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8085 - loss: 0.3993
# Model accuracy: 0.80
# Act: relu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8916 - loss: 0.2733
# Model accuracy: 0.89
# Act: elu
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8275 - loss: 0.3741
# Model accuracy: 0.83
# Act: tanh
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8677 - loss: 0.3009
# Model accuracy: 0.86

# %%
def train(opt,point,epoch,batch,act,loss):
    m = Sequential([Flatten(input_shape=(32,32,3)), Dense(point, activation=act), Dense(2, activation='softmax')])
    m.compile(optimizer=opt, loss=loss, metrics=['accuracy'])
    h = m.fit(x_train, train_vec_labels, validation_data=(x_test,test_vec_labels), epochs=epoch, batch_size=batch, verbose=0)
    print("Act:", act)
    eval_loss, eval_accuracy = m.evaluate(x_test, test_vec_labels)
    print("Model accuracy: %.2f" % eval_accuracy)
    hist_act[act] = h.history['val_accuracy'][-1]
    plt.plot(h.history['accuracy'],'o--')
    plt.plot(h.history['val_accuracy'],'o--')
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
sgd1 = keras.optimizers.SGD(
      learning_rate=0.01,
      weight_decay=1e-6,
      momentum=0.7)
sgd2 = keras.optimizers.SGD(
      learning_rate=0.01,
      weight_decay=1e-6,
      momentum=0.8)
sgd3 = keras.optimizers.SGD(
      learning_rate=0.01,
      weight_decay=1e-6,
      momentum=0.9)
sgd4 = keras.optimizers.SGD(
      learning_rate=0.01,
      weight_decay=1e-6,
      momentum=0.7)
sgd5 = keras.optimizers.SGD(
      learning_rate=0.02,
      weight_decay=1e-6,
      momentum=0.8)
sgd6 = keras.optimizers.SGD(
      learning_rate=0.005,
      weight_decay=1e-6,
      momentum=0.9)
sgd7 = keras.optimizers.SGD(
      learning_rate=0.01,
      weight_decay=1e-5,
      momentum=0.7)
sgd8 = keras.optimizers.SGD(
      learning_rate=0.01,
      weight_decay=1e-6,
      momentum=0.8)
sgd9 = keras.optimizers.SGD(
      learning_rate=0.01,
      weight_decay=1e-7,
      momentum=0.9)

# %%
tf.compat.v1.enable_eager_execution()
point = 128
batch= 8
epoch = 30
losses = ["categorical_crossentropy","mean_squared_error"]
opts = ["adam","sgd",sgd1,sgd2,sgd3,sgd4,sgd5,sgd6,sgd7,sgd8,sgd9]
acts = ["relu", "tanh"]
for act in acts:
    for loss in losses:
        print("Loss:", loss)
        for opt in opts:
            train(opt,point,epoch,batch,act,loss)
            print("OPT:", opt)
# Out:
# Loss: categorical_crossentropy
